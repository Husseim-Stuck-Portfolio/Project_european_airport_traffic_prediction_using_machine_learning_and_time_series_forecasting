# %%
#Import Libraries
import pandas as pd
import numpy as np

#Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

#Import Machine Learning tests
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

#Import Dataset
df = pd.read_csv("../1_RawData/Teen_Mental_Health_Dataset.csv", header=0, index_col=0)

# %%
##Normalizing column headers

df.columns = (
    df.columns
    .str.lower()
    .str.replace('(', '_', regex=False)   # replace ( with _
    .str.replace('/', '_', regex=False)   # replace ( with _
    .str.replace(')', '', regex=False)    # remove )
    .str.replace(r'[^\w\s]', '', regex=True)  # remove other special chars
    .str.replace(' ', '_')                # spaces → underscore
    .str.replace('__', '_')
)
df.columns
# Out:
# Index(['gender', 'daily_social_media_hours', 'platform_usage', 'sleep_hours',
#        'screen_time_before_sleep', 'academic_performance', 'physical_activity',
#        'social_interaction_level', 'stress_level', 'anxiety_level',
#        'addiction_level', 'depression_label'],
#       dtype='object')

# %%
#split cols into different columns 
numerical_cols = df.select_dtypes(include=np.number)
print(numerical_cols)

#be careful because some categorical values my sip into numerical_cols (numbers that represent category)
categorical_cols = df.select_dtypes(exclude=np.number)
print(categorical_cols)
# Out:
#      daily_social_media_hours  sleep_hours  screen_time_before_sleep  \
# age
# 14                        7.9          7.4                       2.9
# 19                        1.9          8.0                       2.9
# 17                        1.3          7.6                       0.5
# 15                        7.4          6.9                       1.6
# 15                        4.7          4.9                       3.0
# ..                        ...          ...                       ...
# 18                        6.8          6.6                       2.0
# 16                        2.3          8.0                       1.9
# 14                        1.7          8.7                       0.7
# 15                        3.9          8.5                       2.1
# 16                        4.7          6.5                       1.0
#
#      academic_performance  physical_activity  stress_level  anxiety_level  \
# age
# 14                   3.01                1.5             2              2
# 19                   3.22                0.8             8              1
# 17                   3.92                0.0             2              4
# 15                   3.48                0.8             1              7
# 15                   2.37                1.4             3              5
# ..                    ...                ...           ...            ...
# 18                   2.76                1.0             3              4
# 16                   2.12                0.4             7              4
# 14                   3.98                0.8             1              1
# 15                   3.19                0.6             7              9
# 16                   2.91                0.9             5              7
#
#      addiction_level  depression_label
# age
# 14                 1                 0
# 19                10                 0
# 17                 2                 0
# 15                 9                 0
# 15                 2                 0
# ..               ...               ...
# 18                 4                 0
# 16                 4                 0
# 14                 1                 0
# 15                 9                 0
# 16                 3                 0
#
# [1200 rows x 9 columns]
#      gender platform_usage social_interaction_level
# age
# 14     male      Instagram                      low
# 19   female         TikTok                     high
# 17   female      Instagram                     high
# 15     male         TikTok                   medium
# 15   female           Both                   medium
# ..      ...            ...                      ...
# 18   female      Instagram                      low
# 16     male           Both                     high
# 14   female           Both                     high
# 15     male           Both                     high
# 16   female         TikTok                   medium
#
# [1200 rows x 3 columns]

# %%
df.head()
# Out:
#      gender  daily_social_media_hours platform_usage  sleep_hours  \
# age
# 14     male                       7.9      Instagram          7.4
# 19   female                       1.9         TikTok          8.0
# 17   female                       1.3      Instagram          7.6
# 15     male                       7.4         TikTok          6.9
# 15   female                       4.7           Both          4.9
#
#      screen_time_before_sleep  academic_performance  physical_activity  \
# age
# 14                        2.9                  3.01                1.5
# 19                        2.9                  3.22                0.8
# 17                        0.5                  3.92                0.0
# 15                        1.6                  3.48                0.8
# 15                        3.0                  2.37                1.4
#
#     social_interaction_level  stress_level  anxiety_level  addiction_level  \
# age
# 14                       low             2              2                1
# 19                      high             8              1               10
# 17                      high             2              4                2
# 15                    medium             1              7                9
# 15                    medium             3              5                2
#
#      depression_label
# age
# 14                  0
# 19                  0
# 17                  0
# 15                  0
# 15                  0

# %%
#possibly drop the following columns as they include several NullValues: 



#Explanation

# FLT_DEP_IFR_2	Number of IFR departures	278
# FLT_ARR_IFR_2	Number of IFR arrivals	241
# FLT_TOT_IFR_2	Number total IFR movements	519

# %%
#Column Description

# %%
#Explore all data
print("\n", "Head:","\n", df.head(5))
print("\n", "Tail:","\n", df.tail(5))
print("\n", "Null Values:","\n", df.isna().sum())
print("\n", "Info:","\n", df.info())
print("\n", "Info Memory Usage:","\n", df.info(memory_usage="deep"))
print("\n", "Describe:","\n", df.describe())
print("\n", "Describe All:","\n", df.describe(include="all"))
print("\n", "Shape:","\n", df.shape)
print("\n", "DTypes:","\n", df.dtypes)
print("\n", "Columns:","\n", df.columns)
print("\n", "Index:","\n", df.index)
print("\n", "Values:","\n", df.values)
print("\n", "Empty:","\n", df.empty)
#print("\n", "NDim:","\n", df.ndim)
print("\n", "Size:","\n", df.size)
#print("\n", "Memory True:","\n", df.memory_usage(deep=True))
print("\n", "Transpose:","\n", df.T)
# Out:
#  Head:
#       gender  daily_social_media_hours platform_usage  sleep_hours  \
# age
# 14     male                       7.9      Instagram          7.4
# 19   female                       1.9         TikTok          8.0
# 17   female                       1.3      Instagram          7.6
# 15     male                       7.4         TikTok          6.9
# 15   female                       4.7           Both          4.9
#
#      screen_time_before_sleep  academic_performance  physical_activity  \
# age
# 14                        2.9                  3.01                1.5
# 19                        2.9                  3.22                0.8
# 17                        0.5                  3.92                0.0
# 15                        1.6                  3.48                0.8
# 15                        3.0                  2.37                1.4
#
#     social_interaction_level  stress_level  anxiety_level  addiction_level  \
# age
# 14                       low             2              2                1
# 19                      high             8              1               10
# 17                      high             2              4                2
# 15                    medium             1              7                9
# 15                    medium             3              5                2
#
#      depression_label
# age
# 14                  0
# 19                  0
# 17                  0
# 15                  0
# 15                  0
#
#  Tail:
#       gender  daily_social_media_hours platform_usage  sleep_hours  \
# age
# 18   female                       6.8      Instagram          6.6
# 16     male                       2.3           Both          8.0
# 14   female                       1.7           Both          8.7
# 15     male                       3.9           Both          8.5
# 16   female                       4.7         TikTok          6.5
#
#      screen_time_before_sleep  academic_performance  physical_activity  \
# age
# 18                        2.0                  2.76                1.0
# 16                        1.9                  2.12                0.4
# 14                        0.7                  3.98                0.8
# 15                        2.1                  3.19                0.6
# 16                        1.0                  2.91                0.9
#
#     social_interaction_level  stress_level  anxiety_level  addiction_level  \
# age
# 18                       low             3              4                4
# 16                      high             7              4                4
# 14                      high             1              1                1
# 15                      high             7              9                9
# 16                    medium             5              7                3
#
#      depression_label
# age
# 18                  0
# 16                  0
# 14                  0
# 15                  0
# 16                  0
#
#  Null Values:
#  gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 14 to 16
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    1200 non-null   object
#  1   daily_social_media_hours  1200 non-null   float64
#  2   platform_usage            1200 non-null   object
#  3   sleep_hours               1200 non-null   float64
#  4   screen_time_before_sleep  1200 non-null   float64
#  5   academic_performance      1200 non-null   float64
#  6   physical_activity         1200 non-null   float64
#  7   social_interaction_level  1200 non-null   object
#  8   stress_level              1200 non-null   int64
#  9   anxiety_level             1200 non-null   int64
#  10  addiction_level           1200 non-null   int64
#  11  depression_label          1200 non-null   int64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 121.9+ KB
#
#  Info:
#  None
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 14 to 16
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    1200 non-null   object
#  1   daily_social_media_hours  1200 non-null   float64
#  2   platform_usage            1200 non-null   object
#  3   sleep_hours               1200 non-null   float64
#  4   screen_time_before_sleep  1200 non-null   float64
#  5   academic_performance      1200 non-null   float64
#  6   physical_activity         1200 non-null   float64
#  7   social_interaction_level  1200 non-null   object
#  8   stress_level              1200 non-null   int64
#  9   anxiety_level             1200 non-null   int64
#  10  addiction_level           1200 non-null   int64
#  11  depression_label          1200 non-null   int64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 284.4 KB
#
#  Info Memory Usage:
#  None
#
#  Describe:
#         daily_social_media_hours  sleep_hours  screen_time_before_sleep  \
# count               1200.000000  1200.000000               1200.000000
# mean                   4.536667     6.449417                  1.740333
# std                    2.029599     1.442677                  0.716660
# min                    1.000000     4.000000                  0.500000
# 25%                    2.800000     5.200000                  1.100000
# 50%                    4.500000     6.500000                  1.800000
# 75%                    6.300000     7.600000                  2.400000
# max                    8.000000     9.000000                  3.000000
#
#        academic_performance  physical_activity  stress_level  anxiety_level  \
# count           1200.000000        1200.000000   1200.000000    1200.000000
# mean               2.990383           1.014500      5.445833       5.636667
# std                0.576758           0.582185      2.903290       2.859453
# min                2.000000           0.000000      1.000000       1.000000
# 25%                2.500000           0.500000      3.000000       3.000000
# 50%                2.990000           1.000000      5.000000       6.000000
# 75%                3.480000           1.500000      8.000000       8.000000
# max                4.000000           2.000000     10.000000      10.000000
#
#        addiction_level  depression_label
# count      1200.000000       1200.000000
# mean          5.565000          0.025833
# std           2.830627          0.158704
# min           1.000000          0.000000
# 25%           3.000000          0.000000
# 50%           6.000000          0.000000
# 75%           8.000000          0.000000
# max          10.000000          1.000000
#
#  Describe All:
#         gender  daily_social_media_hours platform_usage  sleep_hours  \
# count    1200               1200.000000           1200  1200.000000
# unique      2                       NaN              3          NaN
# top      male                       NaN      Instagram          NaN
# freq      615                       NaN            411          NaN
# mean      NaN                  4.536667            NaN     6.449417
# std       NaN                  2.029599            NaN     1.442677
# min       NaN                  1.000000            NaN     4.000000
# 25%       NaN                  2.800000            NaN     5.200000
# 50%       NaN                  4.500000            NaN     6.500000
# 75%       NaN                  6.300000            NaN     7.600000
# max       NaN                  8.000000            NaN     9.000000
#
#         screen_time_before_sleep  academic_performance  physical_activity  \
# count                1200.000000           1200.000000        1200.000000
# unique                       NaN                   NaN                NaN
# top                          NaN                   NaN                NaN
# freq                         NaN                   NaN                NaN
# mean                    1.740333              2.990383           1.014500
# std                     0.716660              0.576758           0.582185
# min                     0.500000              2.000000           0.000000
# 25%                     1.100000              2.500000           0.500000
# 50%                     1.800000              2.990000           1.000000
# 75%                     2.400000              3.480000           1.500000
# max                     3.000000              4.000000           2.000000
#
#        social_interaction_level  stress_level  anxiety_level  addiction_level  \
# count                      1200   1200.000000    1200.000000      1200.000000
# unique                        3           NaN            NaN              NaN
# top                      medium           NaN            NaN              NaN
# freq                        416           NaN            NaN              NaN
# mean                        NaN      5.445833       5.636667         5.565000
# std                         NaN      2.903290       2.859453         2.830627
# min                         NaN      1.000000       1.000000         1.000000
# 25%                         NaN      3.000000       3.000000         3.000000
# 50%                         NaN      5.000000       6.000000         6.000000
# 75%                         NaN      8.000000       8.000000         8.000000
# max                         NaN     10.000000      10.000000        10.000000
#
#         depression_label
# count        1200.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            0.025833
# std             0.158704
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
#
#  Shape:
#  (1200, 12)
#
#  DTypes:
#  gender                       object
# daily_social_media_hours    float64
# platform_usage               object
# sleep_hours                 float64
# screen_time_before_sleep    float64
# academic_performance        float64
# physical_activity           float64
# social_interaction_level     object
# stress_level                  int64
# anxiety_level                 int64
# addiction_level               int64
# depression_label              int64
# dtype: object
#
#  Columns:
#  Index(['gender', 'daily_social_media_hours', 'platform_usage', 'sleep_hours',
#        'screen_time_before_sleep', 'academic_performance', 'physical_activity',
#        'social_interaction_level', 'stress_level', 'anxiety_level',
#        'addiction_level', 'depression_label'],
#       dtype='object')
#
#  Index:
#  Index([14, 19, 17, 15, 15, 19, 18, 16, 19, 15,
#        ...
#        17, 19, 13, 13, 17, 18, 16, 14, 15, 16],
#       dtype='int64', name='age', length=1200)
#
#  Values:
#  [['male' 7.9 'Instagram' ... 2 1 0]
#  ['female' 1.9 'TikTok' ... 1 10 0]
#  ['female' 1.3 'Instagram' ... 4 2 0]
#  ...
#  ['female' 1.7 'Both' ... 1 1 0]
#  ['male' 3.9 'Both' ... 9 9 0]
#  ['female' 4.7 'TikTok' ... 7 3 0]]
#
#  Empty:
#  False
#
#  Size:
#  14400
#
#  Transpose:
#  age                              14      19         17      15      15  \
# gender                         male  female     female    male  female
# daily_social_media_hours        7.9     1.9        1.3     7.4     4.7
# platform_usage            Instagram  TikTok  Instagram  TikTok    Both
# sleep_hours                     7.4     8.0        7.6     6.9     4.9
# screen_time_before_sleep        2.9     2.9        0.5     1.6     3.0
# academic_performance           3.01    3.22       3.92    3.48    2.37
# physical_activity               1.5     0.8        0.0     0.8     1.4
# social_interaction_level        low    high       high  medium  medium
# stress_level                      2       8          2       1       3
# anxiety_level                     2       1          4       7       5
# addiction_level                   1      10          2       9       2
# depression_label                  0       0          0       0       0
#
# age                           19         18    16      19      15  ...  \
# gender                    female     female  male  female    male  ...
# daily_social_media_hours     7.4        2.5   4.0     3.3     1.9  ...
# platform_usage              Both  Instagram  Both  TikTok  TikTok  ...
# sleep_hours                  4.4        6.4   4.2     5.0     4.9  ...
# screen_time_before_sleep     2.4        2.4   0.5     2.1     1.5  ...
# academic_performance        2.63       2.63   2.4    2.04    3.77  ...
# physical_activity            0.6        0.7   1.3     0.9     1.1  ...
# social_interaction_level    high        low   low    high    high  ...
# stress_level                   3          2     6       1       1  ...
# anxiety_level                  5          2    10      10       1  ...
# addiction_level                7          5     5       9       4  ...
# depression_label               0          0     0       0       0  ...
#
# age                              17      19      13         13      17  \
# gender                       female    male    male     female    male
# daily_social_media_hours        3.8     8.0     7.8        7.2     2.0
# platform_usage            Instagram  TikTok  TikTok  Instagram    Both
# sleep_hours                     8.4     4.7     5.9        8.1     4.5
# screen_time_before_sleep        0.9     0.5     1.5        2.1     1.7
# academic_performance            3.6    2.18    3.31       2.52    2.65
# physical_activity               1.9     0.6     1.9        0.4     0.0
# social_interaction_level       high  medium    high     medium  medium
# stress_level                      1       8      10          3       9
# anxiety_level                     2       8       1          3       4
# addiction_level                   2       6      10          7       2
# depression_label                  0       1       0          0       0
#
# age                              18    16      14    15      16
# gender                       female  male  female  male  female
# daily_social_media_hours        6.8   2.3     1.7   3.9     4.7
# platform_usage            Instagram  Both    Both  Both  TikTok
# sleep_hours                     6.6   8.0     8.7   8.5     6.5
# screen_time_before_sleep        2.0   1.9     0.7   2.1     1.0
# academic_performance           2.76  2.12    3.98  3.19    2.91
# physical_activity               1.0   0.4     0.8   0.6     0.9
# social_interaction_level        low  high    high  high  medium
# stress_level                      3     7       1     7       5
# anxiety_level                     4     4       1     9       7
# addiction_level                   4     4       1     9       3
# depression_label                  0     0       0     0       0
#
# [12 rows x 1200 columns]

# %%
# Columns Description 
# ### Demographic and Usage Columns
# *   **age**: The age of the participant (typically ranging from 13 to 19 in this dataset).
# *   **gender**: The gender identity of the participant (e.g., male, female).
# *   **daily_social_media_hours**: The average number of hours spent on social media platforms per day.
# *   **platform_usage**: The primary social media platform used (categories: Instagram, TikTok, or Both).
# 
# ### Lifestyle and Academic Columns
# *   **sleep_hours**: The average number of hours of sleep the participant gets per night.
# *   **screen_time_before_sleep**: The average time (in hours) spent on devices immediately before trying to sleep.
# *   **academic_performance**: A numeric score representing grades or academic achievement (typically on a scale similar to GPA).
# *   **physical_activity**: The average daily time or level of physical activity in hours.
# *   **social_interaction_level**: A qualitative assessment of how often or how well the participant interacts socially (categories: low, medium, high).
# 
# ### Mental Health and Outcome Columns
# *   **stress_level**: A self-reported or assessed score representing perceived stress (likely on a scale from 1 to 10).
# *   **anxiety_level**: A score representing the level of anxiety reported (likely on a scale from 1 to 10).
# *   **addiction_level**: A score representing the level of perceived social media dependency (likely on a scale from 1 to 10).
# *   **depression_label**: A binary classification indicator (0 or 1) intended to flag the presence or absence of a clinical depression diagnosis or significant depressive symptoms, which acts as the target variable for predictive modeling.[1]
